# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\getud\\Git\\data-question-6-leopards'

# %%
os.chdir("C:\\Users\\getud\\Git\\data-question-6-leopards")

# %%
pwd
# Out:
# 'C:\\Users\\getud\\Git\\data-question-6-leopards'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import datetime

# %%
#from sqlalchemy import create_engine

# %%
% matplotlib inline

# %% [markdown]
# If the vehicle is in running
# condition the petrol flow is very slow, so the sensors ignore it.
# But if someone stealing the petrol, the petrol flow is very fast.
# If the petrol flow is very fast then the sensor senses it and
# sends the message to the Micro controller. Through LCD
# display one could see the remaining quantity of the petrol in
# petrol tank. The memory device stores the level of the petrol in
# petrol tank.
#
# Anomaly Detection
# Algorithm by introducing a mode as center point. The propose
# algorithm will work on a database level and highlight any
# suspicious entries for further investigation.

# %%
events=pd.read_csv("data/Extranet2.ExactFuelEvents.csv")
events.shape
# Out:
# (8495130, 15)

# %%
#events.head()

# %%
#events_col=['Id', 'ESS_Id', 'EventTimeStamp', 'EquipmentID','DriverID', 'Latitude', 'Longitude','Speed', 'Heading', 'Odometer', 'IgnitionStatus','EFReportReason']

# %%
df_events=events[['Id', 'EventTimeStamp', 'EquipmentID','DriverID', 'Speed',  'Odometer', 'IgnitionStatus']]
df_events.head()
# Out:
#          Id           EventTimeStamp  EquipmentID DriverID  Speed  Odometer  \
# 0  12649083  2017-01-01 00:00:32.387         1992     BATK      0   39895.5
# 1  12649084  2017-01-01 00:01:24.867         1712   TAYANT      0  360378.8
# 2  12649092  2017-01-01 00:04:15.053         1713     RUSR     67  377577.4
# 3  12649102  2017-01-01 00:04:10.260         1585     MCAD      0  513931.8
# 4  12649103  2017-01-01 00:10:13.187         1564     ULAL      3  498691.0
#
#    IgnitionStatus
# 0               2
# 1               1
# 2               1
# 3               1
# 4               1

# %%
df_events_0=df_events[df_events['Speed']==0]

# %%
df_events_0.head(10)
# Out:
#           Id           EventTimeStamp  EquipmentID DriverID  Speed  Odometer  \
# 0   12649083  2017-01-01 00:00:32.387         1992     BATK      0   39895.5
# 1   12649084  2017-01-01 00:01:24.867         1712   TAYANT      0  360378.8
# 3   12649102  2017-01-01 00:04:10.260         1585     MCAD      0  513931.8
# 6   12649105  2017-01-01 00:11:48.803         1693   THOCHA      0  340043.7
# 8   12649107  2017-01-01 00:13:02.450         1992     BATK      0   39895.5
# 9   12649108  2017-01-01 00:13:38.137         1711    FOSJA      0  342948.1
# 11  12649110  2017-01-01 00:15:52.450         1992     BATK      0   39895.6
# 12  12649111  2017-01-01 00:16:24.883         1712   TAYANT      0  360378.8
# 13  12649112  2017-01-01 00:18:45.750         1672     JAML      0  354397.2
# 14  12649113  2017-01-01 00:20:45.750         1672     JAML      0  354397.2
#
#     IgnitionStatus
# 0                2
# 1                1
# 3                1
# 6                1
# 8                1
# 9                2
# 11               2
# 12               1
# 13               1
# 14               1

# %%
#plt.plot_date(data=events, x="Id", y="EventTimeStamp")

# %%
#truck1604=events[events["EquipmentID"]==1604]

# %%
#truck1604.shape

# %%
#Counter(events["EquipmentID"])

# %%
tank_levels=pd.read_csv("data/Extranet2.ExactFuelTankLevels.csv")
tank_levels.head()
#df.drop('column_name', axis=1, inplace=True)
# Out:
#          Id  TankId  TankLevelPercent  TankLevelGallons  ExactFuelEventId
# 0  10391480       1              82.8            165.60          12667508
# 1  10391482       1              72.4            144.80          12667510
# 2  10391505       1              57.1            114.20          12667533
# 3  10391507       1              80.9            161.80          12667535
# 4  10391514       1              56.9            142.25          12667542

# %%
tank_levels.columns
# Out:
# Index(['Id', 'TankId', 'TankLevelPercent', 'TankLevelGallons',
#        'ExactFuelEventId'],
#       dtype='object')

# %%
df_levels=tank_levels[['TankId', 'TankLevelPercent', 'TankLevelGallons',
       'ExactFuelEventId']]

# %%
df_levels.head()
# Out:
#    TankId  TankLevelPercent  TankLevelGallons  ExactFuelEventId
# 0       1              82.8            165.60          12667508
# 1       1              72.4            144.80          12667510
# 2       1              57.1            114.20          12667533
# 3       1              80.9            161.80          12667535
# 4       1              56.9            142.25          12667542

# %%
#tanklevel1604=tank_levels[tank_levels["ExactFuelEventId"]==1604]
#tank_levels["TankId"].unique()
#tanklevel1604

# %%
#tank_levels["TankId"].unique()

# %%
#Counter(tank_levels["Id"]).most_common(10)

# %%
fuel_optimization=pd.read_csv("data/BGEIDSC.EF2EFFP.csv")# TRUCK is the Unique ID for the trucks 
fuel_optimization.head()
# Out:
#    TRUCK ACTIVE SENDFUEL SENDROUTE  TANKCAP  AVGMPG SATTYPE
# 0      1      Y        Y         Y      200     6.0
# 1    243      Y        Y         Y      200     6.0
# 2    244      Y        Y         Y      200     6.0
# 3    245      Y        Y         Y      200     6.0
# 4    246      Y        Y         Y      200     6.0

# %%
df_optmization=fuel_optimization[["TRUCK","TANKCAP"]]
df_optmization.head()
# Out:
#    TRUCK  TANKCAP
# 0      1      200
# 1    243      200
# 2    244      200
# 3    245      200
# 4    246      200

# %%
fuelopt1604=fuel_optimization[fuel_optimization["TRUCK"]==1604]

# %%
fuel_vendor=pd.read_csv("data/BGETCHDATA.PTCHTRANH.csv")

# %%
fuel_vendor.columns
# Out:
# Index(['TRNID', 'TRNDAT', 'TRNTIM', 'TRNTS#', 'TRNTSN', 'TRNSTC', 'TRNST',
#        'TRNDRI', 'TRNUNT', 'TRNPI1', 'TRNPQ1', 'TRNPI2', 'TRNPQ2', 'TRNPI3',
#        'TRNPQ3', 'TRNPI4', 'TRNPQ4', 'TRNPI5', 'TRNPQ5', 'TRNPI6', 'TRNPQ6'],
#       dtype='object')

# %%
df_station = fuel_vendor[['TRNTS#', 'TRNTSN', 'TRNSTC', 'TRNST']]

# %%
df_fuel_transaction=fuel_vendor[['TRNID', 'TRNDAT', 'TRNTIM', 'TRNDRI', 'TRNUNT', 'TRNPI1', 'TRNPQ1' ]]

# %%
df_fuel_transaction.head()
# Out:
#       TRNID    TRNDAT  TRNTIM  TRNDRI  TRNUNT TRNPI1  TRNPQ1
# 0  42574765  20170101      20  ULAL    1564     SCLE    1.00
# 1  42575331  20170101      48  MANRI   1584     ULSD  137.40
# 2  42578678  20170101     134  RUSR    1713     ULSD  137.93
# 3  42578722  20170101     137  FOSJA   1711     ULSD   45.00
# 4  42579695  20170101     302  HICWIL  1837     ULSD  107.36

# %%
#tms=pd.read_csv('data/IBGEFILE.UNITS.csv')

# %%
#performance=pd.read_csv('data/Extranet2.QCPerformanceExtracts.csv')

# %%
#performance.head()

# %%
#Fuel_Transactions = pd.merge(events, tank_levels, how='inner', left_on='Id', right_on = 'ExactFuelEventId')

# %%
#truck1608=Fuel_Transactions[Fuel_Transactions["EquipmentID"]==1608]

# %%
#earthquake_df['magnitude']=earthquake_df['Magnitude'].str.split(' ').str.get(0)
#fuel_vendor['TRNUNT']=fuel_vendor['TRNUNT'].str.split(' ').str.get(0)
#fuel_vendor['TRNUNT']=pd.to_numeric(fuel_vendor['TRNUNT'], downcast='signed',errors='coerce')
#fuel_vendor[fuel_vendor['TRNUNT']==1608]

# %%
#fuel_vendor['TRNUNT']=pd.to_numeric(fuel_vendor['TRNUNT'], downcast='signed',errors='coerce')
#fuel_vendor[fuel_vendor['TRNUNT']==1608]

# %%
#fuel_vendor.head()

# %%
#fuel_vendor['TRNUNT'].unique

# %%
df_events=events[['Id', 'EventTimeStamp', 'EquipmentID','DriverID','Speed', 'Odometer', 'IgnitionStatus']]

# %%
df_levels=tank_levels[['TankId', 'TankLevelPercent', 'TankLevelGallons',
       'ExactFuelEventId']]

# %%
df_optmization=fuel_optimization[["TRUCK","TANKCAP"]]

# %%
df_transaction=fuel_vendor[['TRNID', 'TRNDAT', 'TRNTIM', 'TRNDRI', 'TRNUNT', 'TRNPI1', 'TRNPQ1' ]]

# %%
df_station = fuel_vendor[['TRNTS#', 'TRNTSN', 'TRNSTC', 'TRNST','TRNUNT']]

# %%
df_transaction = df_fuel_transaction[~df_transaction['TRNPI1'].isin(['SCLE', 'CADV', 'DEFD', 'ADD ', 'OIL ', 'UREA', 'DEFC'])]

# %%
df_transaction.dtypes
# Out:
# TRNID       int64
# TRNDAT      int64
# TRNTIM      int64
# TRNDRI     object
# TRNUNT     object
# TRNPI1     object
# TRNPQ1    float64
# dtype: object

# %%
df_transaction['TRNUNT'].dtypes
# Out:
# dtype('O')

# %%
df_transaction['TRNUNT']=pd.to_numeric(df_transaction['TRNUNT'],errors='coerce')
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_transaction.isnull().sum()
# Out:
# TRNID      0
# TRNDAT     0
# TRNTIM     0
# TRNDRI     0
# TRNUNT    85
# TRNPI1     0
# TRNPQ1     0
# dtype: int64

# %%
df_transaction.dropna(axis=0,inplace=True)
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_transaction.isnull().sum()
# Out:
# TRNID     0
# TRNDAT    0
# TRNTIM    0
# TRNDRI    0
# TRNUNT    0
# TRNPI1    0
# TRNPQ1    0
# dtype: int64

# %%
df_transaction['TRNUNT'] = df_transaction['TRNUNT'].astype(int)
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_transaction['TRNUNT'].dtypes
# Out:
# dtype('int32')

# %%
# dropping rows that are not fules from the transaction data frame

# %%
#df_transaction['TRNUNTId']=df_transaction['TRNUNT'].str.split(" ").str.get(0)

# %%
#df_transaction['TRNUNTId'].apply(pd.to_numeric, errors='coerce').head()

# %%
#df_transaction['TRNUNTId'].unique()

# %%
#df_transaction.drop(df_transaction[df_transaction['TRNUNT']=='NAN'])

# %%
# droping observation with speed >30 MpH

# %%
df_events_30=df_events[df_events['Speed'] <= 30]

# %%
# Merge I

# %%
df_event_level = pd.merge(df_events, df_levels, how='inner', left_on='Id', right_on = 'ExactFuelEventId')

# %%
df_event0_level = pd.merge(df_events_0, df_levels, how='inner', left_on='Id', right_on = 'ExactFuelEventId')

# %%
df_event30_level=pd.merge(df_events_30, df_levels, how='inner', left_on='Id', right_on = 'ExactFuelEventId')

# %%
df_event0_level.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4824961 entries, 0 to 4824960
# Data columns (total 11 columns):
# Id                  int64
# EventTimeStamp      object
# EquipmentID         int64
# DriverID            object
# Speed               int64
# Odometer            float64
# IgnitionStatus      int64
# TankId              int64
# TankLevelPercent    float64
# TankLevelGallons    float64
# ExactFuelEventId    int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 441.7+ MB

# %%
# Merging by using all the equipment Ids

# for the df_transaction, TRNUNT is the unique Id to be merged with equipment ID 

# df_optmization TRUCK is the Unique Id that identifies the truck

# %%
#df_event_level_tran = pd.merge(df_event_level, df_transaction, how='inner', left_on='EquipmentID', right_on = 'TRNUNT')

# %%
df_event_30_level_optimization = pd.merge(df_event30_level, df_optmization, how='inner', left_on='EquipmentID', right_on = 'TRUCK')

# %%
df_event_level_optimization = pd.merge(df_event_level, df_optmization, how='inner', left_on='EquipmentID', right_on = 'TRUCK')

# %%
df_event0_level_optimization = pd.merge(df_event0_level, df_optmization, how='inner', left_on='EquipmentID', right_on = 'TRUCK')

# %%
df_event0_level_optimization.shape
# Out:
# (4824961, 13)

# %%
df_event0_level_optimization.head()
# Out:
#          Id           EventTimeStamp  EquipmentID DriverID  Speed  Odometer  \
# 0  12649083  2017-01-01 00:00:32.387         1992     BATK      0   39895.5
# 1  12649107  2017-01-01 00:13:02.450         1992     BATK      0   39895.5
# 2  12649110  2017-01-01 00:15:52.450         1992     BATK      0   39895.6
# 3  12649116  2017-01-01 00:26:22.497         1992     BATK      0   39895.6
# 4  12649191  2017-01-01 01:02:42.683         1992     BATK      0   39923.4
#
#    IgnitionStatus  TankId  TankLevelPercent  TankLevelGallons  \
# 0               2       1              50.7             101.4
# 1               1       1              52.0             104.0
# 2               2       1              50.8             101.6
# 3               1       1              53.2             106.4
# 4               1       1              46.0              92.0
#
#    ExactFuelEventId  TRUCK  TANKCAP
# 0          12649083   1992      200
# 1          12649107   1992      200
# 2          12649110   1992      200
# 3          12649116   1992      200
# 4          12649191   1992      200

# %%
df_event0_level_optimization.drop(["ExactFuelEventId","Speed" ,"TankId", "TRUCK"], axis=1,inplace=True)

# %%
df_event0_level_optimization.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4824961 entries, 0 to 4824960
# Data columns (total 9 columns):
# Id                  int64
# EventTimeStamp      object
# EquipmentID         int64
# DriverID            object
# Odometer            float64
# IgnitionStatus      int64
# TankLevelPercent    float64
# TankLevelGallons    float64
# TANKCAP             int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 368.1+ MB

# %%
df_event_level_optimization.shape
# Out:
# (7908410, 13)

# %%
df_event_level_optimization.drop(['TankId'], axis=1,inplace=True)

# %%
#df_all = pd.merge(df_event_30_level_optimization, df_transaction, how='inner', left_on='EquipmentID', right_on = 'TRNUNT')

# %%
df1992=df_event_level_optimization[df_event_level_optimization["EquipmentID"]==1992]

# %%
df1992.set_index("EventTimeStamp", inplace=True)

# %%
plt.figure(figsize=(12,3))

plt.hist('TankLevelPercent' , data=df1992 )
# Out:
# (array([ 114.,  345.,  827., 1216., 2047., 2026., 2260., 2006., 1812.,
#         3206.]),
#  array([  0.1 ,  10.09,  20.08,  30.07,  40.06,  50.05,  60.04,  70.03,
#          80.02,  90.01, 100.  ]),
#  <a list of 10 Patch objects>)

# %%
df_event_level_optimization.to_csv('df_event_level_optimization.csv',sep=',', encoding='utf-8')

# %%
df_transaction.to_csv('df_transaction.csv',sep=',', encoding='utf-8')

# %%
df_transaction=pd.read_csv("df_transaction.csv")

# %%
type(df_transaction['TRNDAT'])
# Out:
# pandas.core.series.Series

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103971 entries, 0 to 103970
# Data columns (total 8 columns):
# Unnamed: 0    103971 non-null int64
# TRNID         103971 non-null int64
# TRNDAT        103971 non-null int64
# TRNTIM        103971 non-null int64
# TRNDRI        103971 non-null object
# TRNUNT        103971 non-null int64
# TRNPI1        103971 non-null object
# TRNPQ1        103971 non-null float64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 6.3+ MB

# %%
df_transaction["TRNDAT"] = pd.to_datetime(df_transaction["TRNDAT"], format = "%Y%m%d")

# %%
d = datetime.datetime.strptime('2011-06-09', '%Y-%m-%d')
>>> d.strftime('%b %d,%Y')
# Out:
# 'Jun 09,2011'

# %%
df_transaction.head()
# Out:
#    Unnamed: 0     TRNID     TRNDAT  TRNTIM  TRNDRI  TRNUNT TRNPI1  TRNPQ1
# 0           1  42575331 2017-01-01      48  MANRI     1584   ULSD  137.40
# 1           2  42578678 2017-01-01     134  RUSR      1713   ULSD  137.93
# 2           3  42578722 2017-01-01     137  FOSJA     1711   ULSD   45.00
# 3           4  42579695 2017-01-01     302  HICWIL    1837   ULSD  107.36
# 4           5  42579752 2017-01-01     307  BATK      1992   ULSD   93.88

# %%
#df_transaction.to_sql("trans",disk_engine)

# %%
#df_event_level_optimization.to_sql("event_level",disk_engine)

# %%
df_event_30_level_optimization.head()
# Out:
#          Id           EventTimeStamp  EquipmentID DriverID  Speed  Odometer  \
# 0  12649083  2017-01-01 00:00:32.387         1992     BATK      0   39895.5
# 1  12649107  2017-01-01 00:13:02.450         1992     BATK      0   39895.5
# 2  12649110  2017-01-01 00:15:52.450         1992     BATK      0   39895.6
# 3  12649116  2017-01-01 00:26:22.497         1992     BATK      0   39895.6
# 4  12649191  2017-01-01 01:02:42.683         1992     BATK      0   39923.4
#
#    IgnitionStatus  TankId  TankLevelPercent  TankLevelGallons  \
# 0               2       1              50.7             101.4
# 1               1       1              52.0             104.0
# 2               2       1              50.8             101.6
# 3               1       1              53.2             106.4
# 4               1       1              46.0              92.0
#
#    ExactFuelEventId  TRUCK  TANKCAP
# 0          12649083   1992      200
# 1          12649107   1992      200
# 2          12649110   1992      200
# 3          12649116   1992      200
# 4          12649191   1992      200

# %%
BATK=df_event_30_level_optimization[df_event_30_level_optimization['DriverID']=='BATK']

# %%
BATK1992=BATK[BATK["EquipmentID"]==1992]

# %%
BATK.EquipmentID.unique() # He drove three vechiles
# Out:
# array([1992, 1631, 1562], dtype=int64)

# %%
BATK.shape
# Out:
# (7819, 13)

# %%
df_transaction.head()
# Out:
#    Unnamed: 0     TRNID     TRNDAT  TRNTIM  TRNDRI  TRNUNT TRNPI1  TRNPQ1
# 0           1  42575331 2017-01-01      48  MANRI     1584   ULSD  137.40
# 1           2  42578678 2017-01-01     134  RUSR      1713   ULSD  137.93
# 2           3  42578722 2017-01-01     137  FOSJA     1711   ULSD   45.00
# 3           4  42579695 2017-01-01     302  HICWIL    1837   ULSD  107.36
# 4           5  42579752 2017-01-01     307  BATK      1992   ULSD   93.88

# %%
BATK_transaction=df_transaction[df_transaction["TRNDRI"]=='BATK  ']

# %%
BATK_transaction["TRNDAT"] = pd.to_datetime(BATK_transaction["TRNDAT"], format = "%yyyy" )
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
BATK_transaction['TRNDAT'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
#BATK['EventTimeStamp'] =  pd.to_datetime(BATK['EventTimeStamp'], infer_datetime_format=True)

# %%
BATK['EventTimeStamp'] = BATK['EventTimeStamp'].apply(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
BATK['EventTimeStamp'].dtypes
# Out:
# dtype('O')

# %%
BATK['EventTimeStamp'] =  pd.to_datetime(BATK['EventTimeStamp'], infer_datetime_format=True)
# Out:
# C:\Users\getud\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
BATK.head()
# Out:
#          Id EventTimeStamp  EquipmentID DriverID  Speed  Odometer  \
# 0  12649083     2017-01-01         1992     BATK      0   39895.5
# 1  12649107     2017-01-01         1992     BATK      0   39895.5
# 2  12649110     2017-01-01         1992     BATK      0   39895.6
# 3  12649116     2017-01-01         1992     BATK      0   39895.6
# 4  12649191     2017-01-01         1992     BATK      0   39923.4
#
#    IgnitionStatus  TankId  TankLevelPercent  TankLevelGallons  \
# 0               2       1              50.7             101.4
# 1               1       1              52.0             104.0
# 2               2       1              50.8             101.6
# 3               1       1              53.2             106.4
# 4               1       1              46.0              92.0
#
#    ExactFuelEventId  TRUCK  TANKCAP
# 0          12649083   1992      200
# 1          12649107   1992      200
# 2          12649110   1992      200
# 3          12649116   1992      200
# 4          12649191   1992      200

# %%
BATK['EventTimeStamp'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
BATK_transaction.head()
# Out:
#       Unnamed: 0     TRNID     TRNDAT  TRNTIM  TRNDRI  TRNUNT TRNPI1  TRNPQ1
# 4              5  42579752 2017-01-01     307  BATK      1992   ULSD   93.88
# 96           130  42627627 2017-01-02     118  BATK      1992   ULSD   98.68
# 757         1097  42958109 2017-01-05     226  BATK      1992   ULSD   88.31
# 1066        1532  43105362 2017-01-06     504  BATK      1992   ULSD  150.08
# 1513        2152  43316027 2017-01-08     316  BATK      1992   ULSD  110.05

# %%
#BATK['EventTimeStamp'] = BATK['EventTimeStamp'].apply(lambda x: dt.datetime.strftime(x, '%Y-%m-%d'))

# %%
#BATK['EventTimeStamp'] =  pd.to_datetime(BATK['EventTimeStamp'], infer_datetime_format=True)

# %%
BATK_ALL=pd.merge(BATK, BATK_transaction,  how='inner', left_on='EventTimeStamp', right_on ='TRNDAT' )

# %%
BATK_ALL.shape
# Out:
# (4233, 21)

# %%
BATK_ALL.set_index('EventTimeStamp', inplace=True)

# %%
BATK_ALL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4233 entries, 2017-01-01 to 2017-03-27
# Data columns (total 20 columns):
# Id                  4233 non-null int64
# EquipmentID         4233 non-null int64
# DriverID            4233 non-null object
# Speed               4233 non-null int64
# Odometer            4233 non-null float64
# IgnitionStatus      4233 non-null int64
# TankId              4233 non-null int64
# TankLevelPercent    4233 non-null float64
# TankLevelGallons    4233 non-null float64
# ExactFuelEventId    4233 non-null int64
# TRUCK               4233 non-null int64
# TANKCAP             4233 non-null int64
# Unnamed: 0          4233 non-null int64
# TRNID               4233 non-null int64
# TRNDAT              4233 non-null datetime64[ns]
# TRNTIM              4233 non-null int64
# TRNDRI              4233 non-null object
# TRNUNT              4233 non-null int64
# TRNPI1              4233 non-null object
# TRNPQ1              4233 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(12), object(3)
# memory usage: 694.5+ KB

# %%
#BATK_ALL["Odometer_diff"]= pd.rolling_apply(BATK_ALL['Odometer'], 2, lambda x: x[1] - x[0])

# %%
BATK_ALL["Odometer_diff_2"]=BATK_ALL['Odometer'] - BATK_ALL['Odometer'].shift(1)

# %%
len(BATK_ALL["ExactFuelEventId"].unique())
# Out:
# 4210

# %%
BATK_ALL["TankLevelGallons_diff"]= BATK_ALL['TankLevelGallons'] -  BATK_ALL['TankLevelGallons'].shift(1)

# %%
BATK_ALL["Odo_diff"]= BATK_ALL['Odometer'] -  BATK_ALL['Odometer'].shift(1)

# %%
BATK_ALL["MPG"]=BATK_ALL["Odo_diff"]/BATK_ALL["TankLevelGallons_diff"]

# %%
plt.plot(BATK_ALL["Odometer"] )

# %%
odometerreading.describe()
# Out:
# count      4232.000000
# mean         99.451465
# std        9995.197502
# min     -397613.900000
# 25%           0.000000
# 50%           0.000000
# 75%           0.400000
# max      397840.200000
# Name: Odometer, dtype: float64

# %%
tanklevel.describe()
# Out:
# count    4232.000000
# mean       -0.000699
# std        26.312123
# min      -183.200000
# 25%        -1.600000
# 50%         0.000000
# 75%         0.200000
# max       199.600000
# Name: TankLevelGallons, dtype: float64

# %%
df=[]
df.append(tanklevel)

# %%
df.append(odometerreading)

# %%
df
# Out:
# [EventTimeStamp
#  2017-01-01       NaN
#  2017-01-01      2.60
#  2017-01-01     -2.40
#  2017-01-01      4.80
#  2017-01-01    -14.40
#  2017-01-01     -7.60
#  2017-01-01      5.80
#  2017-01-01      0.00
#  2017-01-01      4.80
#  2017-01-01      0.20
#  2017-01-01      0.60
#  2017-01-01     -2.60
#  2017-01-01      0.40
# 2017-01-01      12649289         1992     BATK      2   39938.6
# 2017-01-01      12649290         1992     BATK      0   39938.6
#
#                 IgnitionStatus  TankId  TankLevelPercent  TankLevelGallons  \
# EventTimeStamp
# 2017-01-01                   2       1              50.7             101.4
# 2017-01-01                   1       1              52.0             104.0
# 2017-01-01                   2       1              50.8             101.6
# 2017-01-01                   1       1              53.2             106.4
# 2017-01-01                   1       1              46.0              92.0
# 2017-01-01                   2       1              42.2              84.4
# 2017-01-01                   2       1              45.1              90.2
# 2017-01-01                   2       1              45.1              90.2
# 2017-01-01                   1       1              47.5              95.0
# 2017-01-01                   2       1              47.6              95.2
#
#                 ExactFuelEventId           ...               TRNDAT  TRNTIM  \
# EventTimeStamp                             ...
# 2017-01-01              12649083           ...           2017-01-01     307
# 2017-01-01              12649107           ...           2017-01-01     307
# 2017-01-01              12649110           ...           2017-01-01     307
# 2017-01-01              12649116           ...           2017-01-01     307
# 2017-01-01              12649191           ...           2017-01-01     307
# 2017-01-01              12649220           ...           2017-01-01     307
# 2017-01-01              12649230           ...           2017-01-01     307
# 2017-01-01              12649231           ...           2017-01-01     307
# 2017-01-01              12649289           ...           2017-01-01     307
# 2017-01-01              12649290           ...           2017-01-01     307
#
#                 TRNDRI  TRNUNT TRNPI1  TRNPQ1 Odometer_diff_2  \
# EventTimeStamp
# 2017-01-01      BATK      1992   ULSD   93.88             NaN
# 2017-01-01      BATK      1992   ULSD   93.88             0.0
# 2017-01-01      BATK      1992   ULSD   93.88             0.1
# 2017-01-01      BATK      1992   ULSD   93.88             0.0
# 2017-01-01      BATK      1992   ULSD   93.88            27.8
# 2017-01-01      BATK      1992   ULSD   93.88            14.9
# 2017-01-01      BATK      1992   ULSD   93.88             0.1
# 2017-01-01      BATK      1992   ULSD   93.88             0.0
# 2017-01-01      BATK      1992   ULSD   93.88             0.2
# 2017-01-01      BATK      1992   ULSD   93.88             0.0
#
#                 TankLevelGallons_diff TRNPQ1_diff  TankLevelGallons_diff2
# EventTimeStamp
# 2017-01-01                        NaN         NaN                   104.0
# 2017-01-01                        2.6         0.0                   101.6
# 2017-01-01                       -2.4         0.0                   106.4
# 2017-01-01                        4.8         0.0                    92.0
# 2017-01-01                      -14.4         0.0                    84.4
# 2017-01-01                       -7.6         0.0                    90.2
# 2017-01-01                        5.8         0.0                    90.2
# 2017-01-01                        0.0         0.0                    95.0
# 2017-01-01                        4.8         0.0                    95.2
# 2017-01-01                        0.2         0.0                    95.8
#
# [10 rows x 24 columns]

# %%
#droping negative odo meter differences 
#BATK_ALL.drop(BATK_ALL[BATK_ALL["Odometer_diff_2"] < 0 ].index)

# %%
BATK_ALL_df= BATK_ALL[BATK_ALL["Odometer_diff_2"] > 1.0]
BATK_ALL_df
# Out:
#                       Id  EquipmentID DriverID  Speed  Odometer  \
# EventTimeStamp
# 2017-01-01      12649191         1992     BATK      0   39923.4
# 2017-01-01      12649220         1992     BATK      0   39938.3
# 2017-01-01      12649369         1992     BATK      0   39964.2
# 2017-03-15                28.7                  -5.06
# 2017-03-15                 2.5                  -3.91
# 2017-03-15                99.5                 -23.92
# 2017-03-15                 1.5                   0.46
# 2017-03-15                 5.7                   3.45
# 2017-03-15               128.5                 -28.75
# 2017-03-16               213.7                 -88.78
# 2017-03-16               130.1                 -28.29
# 2017-03-16                13.6                  -7.36
# 2017-03-19               447.1                -123.28
# 2017-03-24               373.6                  -1.38
# 2017-03-24                 5.8                 -13.34
# 2017-03-24                 6.1                 -13.57
# 2017-03-24                 7.5                 -16.33
# 2017-03-24                22.3                  -7.59
# 2017-03-27               469.5                -140.07
# 2017-03-27               136.4                 -85.79
# 2017-03-27                53.5                  -1.84
# 2017-03-27                30.6                  -0.69
# 2017-03-27                22.9                 -23.23
# 2017-03-27                 5.0                  -8.97
#
# [823 rows x 22 columns]

# %%
BATK_ALL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4233 entries, 2017-01-01 to 2017-03-27
# Data columns (total 22 columns):
# Id                       4233 non-null int64
# EquipmentID              4233 non-null int64
# DriverID                 4233 non-null object
# Speed                    4233 non-null int64
# Odometer                 4233 non-null float64
# IgnitionStatus           4233 non-null int64
# TankId                   4233 non-null int64
# TankLevelPercent         4233 non-null float64
# TankLevelGallons         4233 non-null float64
# ExactFuelEventId         4233 non-null int64
# TRUCK                    4233 non-null int64
# TANKCAP                  4233 non-null int64
# Unnamed: 0               4233 non-null int64
# TRNID                    4233 non-null int64
# TRNDAT                   4233 non-null datetime64[ns]
# TRNTIM                   4233 non-null int64
# TRNDRI                   4233 non-null object
# TRNUNT                   4233 non-null int64
# TRNPI1                   4233 non-null object
# TRNPQ1                   4233 non-null float64
# Odometer_diff_2          4232 non-null float64
# TankLevelGallons_diff    4232 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(12), object(3)
# memory usage: 920.6+ KB

# %%
BATK_ALL.drop(BATK_ALL[BATK_ALL.Odometer_diff_2 < 1].index)
# Out:
# Empty DataFrame
# Columns: [Id, EquipmentID, DriverID, Speed, Odometer, IgnitionStatus, TankId, TankLevelPercent, TankLevelGallons, ExactFuelEventId, TRUCK, TANKCAP, Unnamed: 0, TRNID, TRNDAT, TRNTIM, TRNDRI, TRNUNT, TRNPI1, TRNPQ1, Odometer_diff_2, TankLevelGallons_diff, TRNPQ1_diff]
# Index: []
#
# [0 rows x 23 columns]

# %%
BATK_ALL
# Out:
# Empty DataFrame
# Columns: [Id, EquipmentID, DriverID, Speed, Odometer, IgnitionStatus, TankId, TankLevelPercent, TankLevelGallons, ExactFuelEventId, TRUCK, TANKCAP, Unnamed: 0, TRNID, TRNDAT, TRNTIM, TRNDRI, TRNUNT, TRNPI1, TRNPQ1, Odometer_diff, Odometer_diff_2, TankLevelGallons_diff]
# Index: []
#
# [0 rows x 23 columns]

# %%
BATK_ALL=BATK_ALL.drop(BATK_ALL[BATK_ALL["Odometer_diff_2"] > 1500 ].index)

# %%
BATK_ALL["MPG"]= BATK_ALL["TankLevelGallons_diff"] / BATK_ALL["Odometer_diff_2"]

# %%
BATK_ALL
# Out:
# Empty DataFrame
# Columns: [Id, EquipmentID, DriverID, Speed, Odometer, IgnitionStatus, TankId, TankLevelPercent, TankLevelGallons, ExactFuelEventId, TRUCK, TANKCAP, Unnamed: 0, TRNID, TRNDAT, TRNTIM, TRNDRI, TRNUNT, TRNPI1, TRNPQ1, Odometer_diff, Odometer_diff_2, TankLevelGallons_diff, MPG]
# Index: []
#
# [0 rows x 24 columns]

# %%
#BATK_ALL["Odometer_diff_2"].unique()

# %%
BATK_ALL[["MPG","TankLevelGallons_diff","Odometer_diff_2"]]
# Out:
# Empty DataFrame
# Columns: [MPG, TankLevelGallons_diff, Odometer_diff_2]
# Index: []

# %%
#BATK_ALL['Id', 'EquipmentID', 'DriverID', 'Speed', 'Odometer', 'IgnitionStatus',  'TankId', 'TankLevelPercent', 'TankLevelGallons', 'ExactFuelEventId',     'TRUCK', 'TANKCAP', 'TRNID', 'TRNDAT', 'TRNTIM', 'TRNDRI',  'TRNUNT', 'TRNPI1', 'TRNPQ1', 'Odometer_diff', 'Odometer_diff_2']

# %%
plt.figure(figsize=(12,3))

plt.plot(BATK_ALL["Odometer_diff_2"])

# %%
plt.figure(figsize=(12,3))

plt.plot(BATK_ALL["MPG"])

# %%
# strip in tow column 
#df[‘name’] = df.name.str.split(" ", expand=True)

# %%
df_event0_level_optimization.head()
# Out:
#          Id           EventTimeStamp  EquipmentID DriverID  Odometer  \
# 0  12649083  2017-01-01 00:00:32.387         1992     BATK   39895.5
# 1  12649107  2017-01-01 00:13:02.450         1992     BATK   39895.5
# 2  12649110  2017-01-01 00:15:52.450         1992     BATK   39895.6
# 3  12649116  2017-01-01 00:26:22.497         1992     BATK   39895.6
# 4  12649191  2017-01-01 01:02:42.683         1992     BATK   39923.4
#
#    IgnitionStatus  TankLevelPercent  TankLevelGallons  TANKCAP
# 0               2              50.7             101.4      200
# 1               1              52.0             104.0      200
# 2               2              50.8             101.6      200
# 3               1              53.2             106.4      200
# 4               1              46.0              92.0      200

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103971 entries, 0 to 103970
# Data columns (total 8 columns):
# Unnamed: 0    103971 non-null int64
# TRNID         103971 non-null int64
# TRNDAT        103971 non-null datetime64[ns]
# TRNTIM        103971 non-null int64
# TRNDRI        103971 non-null object
# TRNUNT        103971 non-null int64
# TRNPI1        103971 non-null object
# TRNPQ1        103971 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(2)
# memory usage: 6.3+ MB

# %%
df_transaction.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
df_transaction.drop(["TRNPI1"], axis=1, inplace=True)

# %%
df_transaction["TRNPI1"].unique()
# Out:
# array(['ULSD', 'FUEL', 'CDSL', 'DSL1', 'BDSL'], dtype=object)

# %%
df_transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103971 entries, 0 to 103970
# Data columns (total 6 columns):
# TRNID     103971 non-null int64
# TRNDAT    103971 non-null datetime64[ns]
# TRNTIM    103971 non-null int64
# TRNDRI    103971 non-null object
# TRNUNT    103971 non-null int64
# TRNPQ1    103971 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 4.8+ MB

# %%
df_transaction.to_csv("df_transaction.csv")

# %%
df_event0_level_optimization.to_csv("df_ELP_0.csv")
